# %%
import pandas as pd

# %%
import numpy as np

# %%
df= pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
#Analyze diabetes data 
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
#display number of rows and columns in data set 
df.shape
# Out:
# (101766, 50)

# %%
#find columns with a mean score 
df.mean()
# Out:
# encounter_id                1.652016e+08
# patient_nbr                 5.433040e+07
# admission_type_id           2.024006e+00
# discharge_disposition_id    3.715642e+00
# admission_source_id         5.754437e+00
# time_in_hospital            4.395987e+00
# num_lab_procedures          4.309564e+01
# num_procedures              1.339730e+00
# num_medications             1.602184e+01
# number_outpatient           3.693572e-01
# number_emergency            1.978362e-01
# number_inpatient            6.355659e-01
# number_diagnoses            7.422607e+00
# dtype: float64

# %%
#Rename columns 
df= df.rename(columns={'time_in_hospital': 'time_spent','num_medications': 'meds', 'number_diagnoses': 'diagnoses'})
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)      ?
# 1        149190     55629189        Caucasian  Female   [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3        500364     82442376        Caucasian    Male   [30-40)      ?
# 4         16680     42519267        Caucasian    Male   [40-50)      ?
# 5         35754     82637451        Caucasian    Male   [50-60)      ?
# 6         55842     84259809        Caucasian    Male   [60-70)      ?
# 7         63768    114882984        Caucasian    Male   [70-80)      ?
# 8         12522     48330783        Caucasian  Female   [80-90)      ?
# 9         15738     63555939        Caucasian  Female  [90-100)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
#display select columns 
df[['race', 'gender', 'age', 'time_spent', 'insulin', 'readmitted', 'meds', 'diagnoses']]
# Out:
#                    race  gender      age  time_spent insulin readmitted  meds  \
# 0             Caucasian  Female   [0-10)           1      No         NO     1
# 1             Caucasian  Female  [10-20)           3      Up        >30    18
# 2       AfricanAmerican  Female  [20-30)           2      No         NO    13
# 3             Caucasian    Male  [30-40)           2      Up         NO    16
# 4             Caucasian    Male  [40-50)           1  Steady         NO     8
# ...                 ...     ...      ...         ...     ...        ...   ...
# 101761  AfricanAmerican    Male  [70-80)           3    Down        >30    16
# 101762  AfricanAmerican  Female  [80-90)           5  Steady         NO    18
# 101763        Caucasian    Male  [70-80)           1    Down         NO     9
# 101764        Caucasian  Female  [80-90)          10      Up         NO    21
# 101765        Caucasian    Male  [70-80)           6      No         NO     3
#
#         diagnoses
# ...

# %%
#new dataframe with select columns 
df1=df[['race', 'gender', 'age', 'time_spent', 'insulin', 'readmitted', 'meds', 'diagnoses']]

# %%
df1.head(5)
# Out:
#               race  gender      age  time_spent insulin readmitted  meds  \
# 0        Caucasian  Female   [0-10)           1      No         NO     1
# 1        Caucasian  Female  [10-20)           3      Up        >30    18
# 2  AfricanAmerican  Female  [20-30)           2      No         NO    13
# 3        Caucasian    Male  [30-40)           2      Up         NO    16
# 4        Caucasian    Male  [40-50)           1  Steady         NO     8
#
#    diagnoses
# 0          1
# 1          9
# 2          6
# 3          7
# 4          5

# %%
#review number of medications by race 
df.groupby(['race'])['meds'].count()
# Out:
# race
# ?                   2273
# AfricanAmerican    19210
# Asian                641
# Caucasian          76099
# Hispanic            2037
# Other               1506
# Name: meds, dtype: int64

# %%
#check for missing values in dataset 
df1.isnull().sum()
# Out:
# race          0
# gender        0
# age           0
# time_spent    0
# insulin       0
# readmitted    0
# meds          0
# diagnoses     0
# dtype: int64

# %%
#pick any group in dataset as an initial comparison point. 
#filter for African American women 
df1.loc[(df1['race'] == 'AfricanAmerican') & (df1['gender'] == 'Female')]
# Out:
#                    race  gender       age  time_spent insulin readmitted  \
# 2       AfricanAmerican  Female   [20-30)           2      No         NO
# 10      AfricanAmerican  Female   [40-50)           9  Steady        >30
# 14      AfricanAmerican  Female   [60-70)           1  Steady        >30
# 22      AfricanAmerican  Female   [70-80)           2      No         NO
# 24      AfricanAmerican  Female   [70-80)           3  Steady         NO
# ...                 ...     ...       ...         ...     ...        ...
# 101696  AfricanAmerican  Female  [90-100)           6      No         NO
# 101711  AfricanAmerican  Female   [80-90)           7      No        >30
# 101730  AfricanAmerican  Female   [70-80)           3      No         NO
# 101760  AfricanAmerican  Female   [60-70)           6    Down        >30
# 101762  AfricanAmerican  Female   [80-90)           5  Steady         NO
#
#         meds  diagnoses
# 2         13          6
# 10        17          9
# ...

# %%
#review data based on steady insulin levels 
df1[df1['insulin'] =='Steady']
# Out:
#                    race  gender       age  time_spent insulin readmitted  \
# 4             Caucasian    Male   [40-50)           1  Steady         NO
# 5             Caucasian    Male   [50-60)           3  Steady        >30
# 6             Caucasian    Male   [60-70)           4  Steady         NO
# 8             Caucasian  Female   [80-90)          13  Steady         NO
# 9             Caucasian  Female  [90-100)          12  Steady         NO
# ...                 ...     ...       ...         ...     ...        ...
# 101752            Other  Female   [40-50)           3  Steady         NO
# 101754        Caucasian  Female   [70-80)           9  Steady        >30
# 101756            Other  Female   [60-70)           2  Steady        >30
# 101757        Caucasian  Female   [70-80)           5  Steady         NO
# 101762  AfricanAmerican  Female   [80-90)           5  Steady         NO
#
#         meds  diagnoses
# 4          8          5
# 5         16          9
# ...

# %%
#Filter by only African American women 
df2= df1.loc[(df1['race'] == 'AfricanAmerican') & (df1['gender'] == 'Female')]

# %%
#now filter by African American women with steady insulin levels 
df3= df2.loc[(df2['insulin'] == 'Steady')]

# %%
df3.head()
# Out:
#                race  gender      age  time_spent insulin readmitted  meds  \
# 10  AfricanAmerican  Female  [40-50)           9  Steady        >30    17
# 14  AfricanAmerican  Female  [60-70)           1  Steady        >30     2
# 24  AfricanAmerican  Female  [70-80)           3  Steady         NO    18
# 30  AfricanAmerican  Female  [60-70)           6  Steady         NO    18
# 52  AfricanAmerican  Female  [40-50)           8  Steady        >30    17
#
#     diagnoses
# 10          9
# 14          8
# 24          6
# 30          9
# 52          9

# %%
#analyze the average number of medications and time spent in hospital for African American women with steady insulin levels 
#mean score for African American women with steady insulin levels 
df3.mean()
# Out:
# time_spent     4.488012
# meds          15.476274
# diagnoses      7.004745
# dtype: float64

# %%
#Average number of medications by age range for African American women 
df3.groupby(['age'])['meds'].mean()
# Out:
# age
# [0-10)       5.750000
# [10-20)      7.295775
# [20-30)     11.488722
# [30-40)     14.867769
# [40-50)     15.642424
# [50-60)     16.386555
# [60-70)     16.654747
# [70-80)     15.453271
# [80-90)     14.737069
# [90-100)    14.042105
# Name: meds, dtype: float64

# %%
#Review of readmitted African Americans 
df3.loc[(df3['race']== 'AfricanAmerican') & (df3['readmitted'] == 'NO')]
# Out:
#                    race  gender      age  time_spent insulin readmitted  meds  \
# 24      AfricanAmerican  Female  [70-80)           3  Steady         NO    18
# 30      AfricanAmerican  Female  [60-70)           6  Steady         NO    18
# 241     AfricanAmerican  Female  [40-50)           1  Steady         NO     8
# 254     AfricanAmerican  Female  [70-80)           5  Steady         NO    13
# 331     AfricanAmerican  Female  [30-40)           8  Steady         NO    30
# ...                 ...     ...      ...         ...     ...        ...   ...
# 101369  AfricanAmerican  Female  [70-80)           3  Steady         NO    19
# 101407  AfricanAmerican  Female  [60-70)           4  Steady         NO    15
# 101552  AfricanAmerican  Female  [60-70)           2  Steady         NO    23
# 101585  AfricanAmerican  Female  [50-60)           1  Steady         NO    10
# 101762  AfricanAmerican  Female  [80-90)           5  Steady         NO    18
#
#         diagnoses
# ...

# %%
import matplotlib.pyplot as plot

# %%
# %matplotlib inline

# %%
#visualize the data for number of meds that African American women are on based on age range 
df3.groupby(['age'])['meds'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
#Visualize how much time is spent in the hospital for African American Women by age range 
df2.groupby(['age'])['time_spent'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
#As shown in graph, African American women between the age of 60-70 are on the most medications than African American women in any other age range. 
#African American women spend an average of 4.5 days in the hospital 

#Next, review & compare data for Caucasian, Asian, and Hispanic women with steady insulin levels

# %%
#Caucasian women 
df4= df1.loc[(df1['race'] == 'Caucasian') & (df1['gender'] == 'Female')]

# %%
#Filter by Caucasian women with steady insulin levels 
df5= df4.loc[(df4['insulin'] == 'Steady')]

# %%
df5.head()
# Out:
#          race  gender       age  time_spent insulin readmitted  meds  \
# 8   Caucasian  Female   [80-90)          13  Steady         NO    28
# 9   Caucasian  Female  [90-100)          12  Steady         NO    18
# 27  Caucasian  Female   [50-60)           2  Steady        >30    11
# 32  Caucasian  Female   [70-80)           6  Steady        >30    16
# 36  Caucasian  Female   [70-80)           3  Steady         NO     8
#
#     diagnoses
# 8           8
# 9           8
# 27          3
# 32          8
# 36          5

# %%
#Compare average for Caucasian women 
df5.mean()
# Out:
# time_spent     4.450835
# meds          16.824959
# diagnoses      7.629162
# dtype: float64

# %%
#Asian women
df6= df1.loc[(df1['race'] == 'Asian') & (df1['gender'] == 'Female')]

# %%
#Asian women with steady insulin levels 
df7= df6.loc[(df6['insulin'] == 'Steady')]

# %%
df7.tail()
# Out:
#          race  gender      age  time_spent insulin readmitted  meds  diagnoses
# 99315   Asian  Female  [40-50)           2  Steady         NO    16          7
# 100691  Asian  Female  [60-70)           2  Steady         NO    14          5
# 101422  Asian  Female  [70-80)          10  Steady         NO    16          9
# 101595  Asian  Female  [70-80)           6  Steady         NO    19          9
# 101666  Asian  Female  [30-40)           4  Steady         NO     5          9

# %%
#Compare average for Asian women  
df7.mean()
# Out:
# time_spent     4.215909
# meds          13.772727
# diagnoses      7.102273
# dtype: float64

# %%
#Hispanic women 
df8= df1.loc[(df1['race'] == 'Hispanic') & (df1['gender'] == 'Female')]

# %%
#Hispanic women with steady insulin levels 
df9= df8.loc[(df8['insulin'] == 'Steady')]

# %%
#Compare average for Hispanic women 
df9.mean()
# Out:
# time_spent     4.029900
# meds          14.780731
# diagnoses      7.063123
# dtype: float64

# %%
df9.head()
# Out:
#           race  gender      age  time_spent insulin readmitted  meds  \
# 456   Hispanic  Female  [60-70)           6  Steady        >30    18
# 1125  Hispanic  Female  [50-60)           1  Steady         NO     8
# 1647  Hispanic  Female  [50-60)           6  Steady         NO     8
# 3153  Hispanic  Female   [0-10)           3  Steady         NO     6
# 3292  Hispanic  Female  [10-20)           2  Steady        >30     6
#
#       diagnoses
# 456           5
# 1125          2
# 1647          2
# 3153          1
# 3292          3

# %%
#Look at African American women in age range of 30-40 
df10= df3.loc[(df3['age'] == '[30-40)')]

# %%
df10.mean()
# Out:
# time_spent     4.066116
# meds          14.867769
# diagnoses      6.297521
# dtype: float64

# %%
#Caucasian women 30-40 age range 
df11= df5.loc[(df5['age'] == '[30-40)')]
df11.mean()
# Out:
# time_spent     3.678571
# meds          14.488095
# diagnoses      6.630952
# dtype: float64

# %%
#Asian women 30-40 age range 
df12= df7.loc[(df7['age'] == '[30-40)')]
df12.mean()
# Out:
# time_spent     3.333333
# meds          10.000000
# diagnoses      7.000000
# dtype: float64

# %%
#Hispanic women 30-40 age range 
df13= df9.loc[(df9['age'] == '[30-40)')]
df13.mean()
# Out:
# time_spent     3.071429
# meds          12.321429
# diagnoses      6.178571
# dtype: float64

# %%
df1.head()
# Out:
#               race   meds
# 0  AfricanAmerican  14.87
# 1        Caucasian  14.48
# 2            Asian  10.00
# 3         Hispanic  12.32

# %%
#Compare meds or time spent or diagnoses of women between the ages of 30-40 with steady insulin levels 
df = pd.DataFrame({'race':['AfricanAmerican', 'Caucasian', 'Asian', 'Hispanic'], 'meds':[14.87, 14.48, 10.00, 12.32]})
ax = df.plot.bar(x='race', y='meds', rot=0)

# %%
#Conclusion African American women between the ages of 30-40, were prescribed the most amount of medications when compared to other races with a steady insulin level.
#On average women of all ages and races spend less than 5 days in the hospital.
